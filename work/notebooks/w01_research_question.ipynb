# %% [markdown]
# <a href="https://colab.research.google.com/github/s-zaid-13/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/s-zaid-13/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I selected the **Refresh / Content Opportunity Scoring** lane.
#
# This lane focuses on identifying which content pages should be reviewed first for refresh or improvement. Instead of trying to update every page, the goal is to rank pages based on evidence so that reviewers can spend their time on the pages with the highest potential impact. I chose this lane because it solves a practical business problem and combines data analysis with machine learning to support better content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision is made by the content or SEO team. They will use the ranked list to decide which pages to review first.
#
# The action is to refresh, expand, improve, or monitor the selected pages.
#
# A wrong recommendation has two possible costs.
#
# 1. If a low-value page is recommended, the team wastes time and resources.
#
# 2. If an important page is missed, the business may lose traffic and improvement opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains **30,000 content records**, which provides a good amount of data for exploring refresh opportunities.
#
# Among these records, **16,262 pages are marked as "down"** in the current trend direction. This suggests that many pages may require review or improvement.
#
# The average number of **90-day impressions is about 5,200**, which indicates that many pages already receive meaningful search visibility. The average **CTR is approximately 0.51**, providing another useful signal for identifying pages that may benefit from content or metadata improvements.
#
# These observations suggest that the dataset contains enough variation and useful signals to support the **Refresh / Content Opportunity Scoring** lane over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

print("Rows, Columns:", df.shape)

print("\nTrend Direction")
print(df["trend_direction"].value_counts())

print("\nAverage 90-day Impressions")
print(df["impressions_90d"].mean())

print("\nAverage CTR")
print(df["ctr"].mean())
# Out:
# Rows, Columns: (30000, 44)
#
# Trend Direction
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#
# Average 90-day Impressions
# 5200.3663
#
# Average CTR
# 0.5107333333333334

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project is intended to provide **decision-support** by identifying pages that appear to be stronger candidates for content review based on observed search and engagement signals.
#
# The analysis can identify patterns, trends, and ranking opportunities that may help prioritize content review. However, it cannot prove that refreshing a page will directly increase traffic or improve search rankings.
#
# The results are based on observed data and should be treated as directional evidence rather than causal proof. This project does not predict Google's ranking algorithm or guarantee that a recommended action will produce a specific outcome. Human review is still required before making content decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
